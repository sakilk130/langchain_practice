# %%
# import sys 
# !{sys.executable} -m pip install langchain_openai langchain langchain_core

# %%
from langchain_openai.chat_models import ChatOpenAI

# %%
chat = ChatOpenAI(
    model_name='llama3.2:3b',
    openai_api_key='ollama', 
    openai_api_base='http://localhost:11434/v1',
    temperature = 0, 
    max_tokens = 100,
    model_kwargs = {
        'seed':365
    }
)

# %%
response = chat.invoke('''I've recently adopted a dog. Could you suggest some dog names?''')

# %%
print(response.content)
# Out:
# Congratulations on adopting a new furry friend!
#
# I'd be happy to help you find the paw-fect name for your dog! Here are some popular and unique name suggestions:
#
# **Classic Dog Names:**
#
# 1. Max
# 2. Bella
# 3. Charlie
# 4. Lucy
# 5. Cooper
# 6. Rocky
# 7. Luna
# 8. Duke
# 9. Daisy
# 10. Buddy
#
# **Unique Dog Names:**
#
# 1. Aurora (for a dog with a celestial personality)
# 2. Sage (a wise and intelligent name for a calm dog)
# 3. Piper (a strong and adventurous name)
# 4. Remi (short for Remy, perfect for a playful dog)
# 5. Indie (independent and free-spirited)
# 6. Caspian (a majestic and elegant name)
# 7. Lyra (musical and poetic)
# 8. Orion (for a bold and fearless dog)
# 9. Clio (a historical and cultured name)
# 10. Zephyr (a windy and carefree name)
#
# **Food-Inspired Dog Names:**
#
# 1. Peanut
# 2. Mocha
# 3. Biscuit
# 4. Pumpkin
# 5. S'mores
# 6. Nugget
# 7. Cookie
# 8. Cinnamon
# 9. Truffle
# 10. Bacon
#
# **Literary and Pop Culture Dog Names:**
#
# 1. Atticus (from "To Kill a Mockingbird")
# 2. Lassie (from the classic TV show)
# 3. Scooby (from the popular cartoon)
# 4. Khaleesi (from "Game of Thrones")
# 5. Yoda (from the Star Wars franchise)
# 6. Gandalf (from J.R.R. Tolkien's books)
# 7. Luna Lovegood (from the Harry Potter series)
# 8. Samwise (from "The Lord of the Rings")
# 9. Dobby (from the Harry Potter series)
# 10. Sherlock (for a dog with a clever and analytical mind)
#
# Remember, the most important thing is to choose a name that you and your dog will love and enjoy using!
#
# What type of name are you leaning towards?
