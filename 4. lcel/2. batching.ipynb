# %% [markdown]
# # Batching

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

# %%
chat_template = ChatPromptTemplate.from_messages(
    [
        ('human', "I've recently adopted a {pet} which is a {breed}. Could you suggest several training tips?")
    ]
)

# %%
chat = ChatOpenAI(
    model_name='llama3.2:3b',
    openai_api_key='ollama', 
    openai_api_base='http://localhost:11434/v1',
    temperature = 0, 
    max_tokens = 100,
    model_kwargs = {
        'seed':365
    }
)
# Out:
# /opt/anaconda3/envs/ai-ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3519: UserWarning: Parameters {'seed'} should be specified explicitly. Instead they were passed in as part of `model_kwargs` parameter.
#   if await self.run_code(code, result, async_=asy):

# %%
chain = chat_template | chat

# %%
chain.invoke(
    {
        'pet':'dog',
        'breed':'shepherd'
    }
)
# Out:
# AIMessage(content='Congratulations on adopting your new furry friend! As a shepherd, your dog has a strong herding instinct and may require some special training to channel that energy into positive behaviors. Here are some training tips tailored for your shepherd:\n\n1. **Socialization is key**: Shepherds can be protective of their flock (family) and may become wary of strangers. Socialize your dog extensively, especially during the critical puppy socialization period (8-11 weeks). Introduce them to various environments, people, animals, and situations to help build confidence.\n2. **Basic obedience training**: Establish a strong foundation in basic obedience commands like "sit," "stay," "come," and "leave it." Use positive reinforcement techniques, such as treats and praise, to encourage good behavior.\n3. **Herding instinct management**: Shepherds are bred to herd, so it\'s essential to manage their herding instinct. Provide your dog with alternative outlets for this energy, like:\n * Playing fetch or agility games\n * Engaging in obedience training exercises that mimic herding movements (e.g., "close" and "stay")\n * Participating in dog sports like agility, flyball, or herding competitions\n4. **Boundary setting**: Shepherds can be strong-willed and may test boundaries. Establish clear rules and boundaries, and consistently enforce them using positive reinforcement techniques.\n5. **Positive reinforcement training**: Focus on positive reinforcement training methods, which emphasize rewarding desired behaviors rather than punishing undesired ones. This approach helps build trust and strengthens the bond between you and your dog.\n6. **Desensitization and counterconditioning**: If your shepherd has a strong prey drive or herding instinct that\'s causing problems (e.g., chasing small animals), use desensitization and counterconditioning techniques to help them associate these stimuli with positive outcomes.\n7. **Exercise and mental stimulation**: Provide regular exercise, such as daily walks, runs, or playtime, to keep your shepherd physically and mentally stimulated. Engage their mind with puzzle toys, scent work, or obedience training exercises.\n8. **Consistency and patience**: Training a shepherd requires consistency, patience, and understanding of their breed-specific traits. Be prepared for setbacks and adjust your approach as needed.\n\nSome additional tips specific to shepherds:\n\n* Be aware of their tendency to "protect" their family and territory. Manage this instinct by providing a safe space for them to relax and engage in calm activities.\n* Shepherds can be prone to anxiety or stress. Monitor their behavior and provide plenty of reassurance, exercise, and mental stimulation to help manage these issues.\n\nRemember that every dog is unique, so it\'s essential to tailor your training approach to your shepherd\'s individual needs, personality, and breed-specific traits. With patience, consistency, and positive reinforcement, you can develop a strong bond with your new furry friend and help them become a well-behaved companion.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 592, 'prompt_tokens': 43, 'total_tokens': 635, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'llama3.2:3b', 'system_fingerprint': 'fp_ollama', 'id': 'chatcmpl-579', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dcf9f-98cc-7cc0-98c4-44d9e856f485-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 592, 'total_tokens': 635, 'input_token_details': {}, 'output_token_details': {}})

# %%
# %%time
chain.batch(
    [
        {
            'pet':'dog', 
            'breed':'shepherd'
        }, 
        {
            'pet':'dragon', 
            'breed':'night fury'
            }
    ]
)
# Out:
# CPU times: user 11.7 ms, sys: 4.7 ms, total: 16.4 ms
# Wall time: 16.9 s
# [AIMessage(content='Congratulations on adopting your new furry friend! As a shepherd, your dog has a strong herding instinct and may require some special training to channel that energy into positive behaviors. Here are some training tips tailored for your shepherd:\n\n1. **Socialization is key**: Shepherds can be protective of their flock (family) and may become wary of strangers. Socialize your dog extensively, especially during the critical puppy socialization period (8-11 weeks). Introduce them to various environments, people, animals, and situations to help build confidence.\n2. **Basic obedience training**: Establish a strong foundation in basic obedience commands like "sit," "stay," "come," and "leave it." Use positive reinforcement techniques, such as treats and praise, to encourage good behavior.\n3. **Herding instinct management**: Shepherds are bred to herd, so it\'s essential to manage their herding instinct. Provide your dog with alternative outlets for this energy, like:\n * Playing fetch or agility games\n * Engaging in obedience training exercises that mimic herding movements (e.g., "close" and "stay")\n * Participating in dog sports like agility, flyball, or herding competitions\n4. **Boundary setting**: Shepherds can be strong-willed and may test boundaries. Establish clear rules and boundaries, and consistently enforce them using positive reinforcement techniques.\n5. **Positive reinforcement training**: Focus on positive reinforcement training methods, which emphasize rewarding desired behaviors rather than punishing undesired ones. This approach helps build trust and strengthens the bond between you and your dog.\n6. **Desensitization and counterconditioning**: If your shepherd has a strong prey drive or herding instinct that\'s causing problems (e.g., chasing small animals), use desensitization and counterconditioning techniques to help them associate these stimuli with positive outcomes.\n7. **Exercise and mental stimulation**: Provide regular exercise, such as daily walks, runs, or playtime, to keep your shepherd physically and mentally stimulated. Engage their mind with puzzle toys, scent work, or obedience training exercises.\n8. **Consistency and patience**: Training a shepherd requires consistency, patience, and understanding of their breed-specific traits. Be prepared for setbacks and adjust your approach as needed.\n\nSome additional tips specific to shepherds:\n\n* Be aware of their tendency to "protect" their family and territory. Manage this instinct by providing a safe space for them to relax and engage in calm activities.\n* Shepherds can be prone to anxiety or stress. Monitor their behavior and provide plenty of reassurance, exercise, and mental stimulation to help manage these issues.\n\nRemember that every dog is unique, so it\'s essential to tailor your training approach to your shepherd\'s individual needs, personality, and breed-specific traits. With patience, consistency, and positive reinforcement, you can develop a strong bond with your new furry friend and help them become a well-behaved companion.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 592, 'prompt_tokens': 43, 'total_tokens': 635, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'llama3.2:3b', 'system_fingerprint': 'fp_ollama', 'id': 'chatcmpl-621', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dcf9f-be36-7652-992d-e3484d8fe154-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 592, 'total_tokens': 635, 'input_token_details': {}, 'output_token_details': {}}),
#  AIMessage(content='Congratulations on adopting a Night Fury dragon! Training a Night Fury can be challenging due to their independent nature and tendency to be fiercely protective of themselves. Here are some training tips to help you establish a strong bond with your new companion:\n\n1. **Establish trust**: Night Furies are naturally wary of humans, so it\'s essential to earn their trust gradually. Start by offering food and letting them approach you on their own terms.\n2. **Use positive reinforcement**: Reward your dragon with treats, praise, or affection when they exhibit desired behavior, such as responding to commands or performing tricks.\n3. **Be consistent**: Night Furies thrive on routine, so establish a regular training schedule and stick to it. This will help them understand what\'s expected of them.\n4. **Use verbal cues**: Night Furies respond well to vocal commands, so use clear, concise phrases like "sit," "stay," or "come." Avoid yelling or using harsh tones, as this can create anxiety.\n5. **Practice obedience exercises**: Teach your dragon to follow basic commands, such as walking on a leash, performing tricks, or responding to hand signals.\n6. **Respect their boundaries**: Night Furies are fiercely protective of themselves and may become aggressive if they feel threatened or scared. Always respect their personal space and avoid pushing them beyond their comfort zone.\n7. **Provide mental stimulation**: Engage your dragon\'s mind with puzzle toys, problem-solving exercises, or interactive games to keep them mentally stimulated and prevent boredom.\n8. **Use physical exercise**: Night Furies are naturally athletic, so engage them in physical activities like flying, agility training, or obstacle courses to burn off energy and strengthen your bond.\n9. **Be patient**: Training a Night Fury requires time, patience, and understanding. Don\'t expect immediate results, as they may take weeks or even months to adjust to new commands and routines.\n10. **Seek professional guidance**: If you\'re struggling with training your Night Fury or experiencing behavioral issues, consider consulting with a professional dragon trainer or behaviorist for personalized advice.\n\nRemember, every dragon is unique, so be prepared to adapt these tips to suit your Night Fury\'s individual needs and personality.\n\nAdditional resources:\n\n* The Dragon Rider\'s Handbook (a comprehensive guide to dragon care and training)\n* The Night Fury Breed Guide (specific information on the Night Fury breed, including their behavior, habits, and training requirements)\n* Online forums and communities dedicated to dragon breeding and training\n\nStay safe, and enjoy your journey with your new Night Fury companion!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 512, 'prompt_tokens': 44, 'total_tokens': 556, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'llama3.2:3b', 'system_fingerprint': 'fp_ollama', 'id': 'chatcmpl-406', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dcf9f-be38-78e0-bef2-e8da97bfaaf8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 44, 'output_tokens': 512, 'total_tokens': 556, 'input_token_details': {}, 'output_token_details': {}})]

# %%
# %%time
chain.invoke(
    {
        'pet':'dog', 
        'breed':'shepherd'
    }
)
# Out:
# CPU times: user 6.38 ms, sys: 1.79 ms, total: 8.17 ms
# Wall time: 9.03 s
# AIMessage(content='Congratulations on adopting your new furry friend! As a shepherd, your dog has a strong herding instinct and may require some special training to channel that energy into positive behaviors. Here are some training tips tailored for your shepherd:\n\n1. **Socialization is key**: Shepherds can be protective of their flock (family) and may become wary of strangers. Socialize your dog extensively, especially during the critical puppy socialization period (8-11 weeks). Introduce them to various environments, people, animals, and situations to help build confidence.\n2. **Basic obedience training**: Establish a strong foundation in basic obedience commands like "sit," "stay," "come," and "leave it." Use positive reinforcement techniques, such as treats and praise, to encourage good behavior.\n3. **Herding instinct management**: Shepherds are bred to herd, so it\'s essential to manage their herding instinct. Provide your dog with alternative outlets for this energy, like:\n * Playing fetch or agility games\n * Engaging in obedience training exercises that mimic herding movements (e.g., "close" and "stay")\n * Participating in dog sports like agility, flyball, or herding competitions\n4. **Boundary setting**: Shepherds can be strong-willed and may test boundaries. Establish clear rules and boundaries, and consistently enforce them using positive reinforcement techniques.\n5. **Positive reinforcement training**: Focus on positive reinforcement training methods, which emphasize rewarding desired behaviors rather than punishing undesired ones. This approach helps build trust and strengthens the bond between you and your dog.\n6. **Desensitization and counterconditioning**: If your shepherd has a strong prey drive or herding instinct that\'s causing problems (e.g., chasing small animals), use desensitization and counterconditioning techniques to help them associate these stimuli with positive outcomes.\n7. **Exercise and mental stimulation**: Provide regular exercise, such as daily walks, runs, or playtime, to keep your shepherd physically and mentally stimulated. Engage their mind with puzzle toys, scent work, or obedience training exercises.\n8. **Consistency and patience**: Training a shepherd requires consistency, patience, and understanding of their breed-specific traits. Be prepared for setbacks and adjust your approach as needed.\n\nSome additional tips specific to shepherds:\n\n* Be aware of their tendency to "protect" their family and territory. Manage this instinct by providing a safe space for them to relax and engage in calm activities.\n* Shepherds can be prone to anxiety or stress. Monitor their behavior and provide plenty of reassurance, exercise, and mental stimulation to help manage these issues.\n\nRemember that every dog is unique, so it\'s essential to tailor your training approach to your shepherd\'s individual needs, personality, and breed-specific traits. With patience, consistency, and positive reinforcement, you can develop a strong bond with your new furry friend and help them become a well-behaved companion.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 592, 'prompt_tokens': 43, 'total_tokens': 635, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'llama3.2:3b', 'system_fingerprint': 'fp_ollama', 'id': 'chatcmpl-975', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dcfa0-005f-7d92-8876-62f6b0502f8b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 592, 'total_tokens': 635, 'input_token_details': {}, 'output_token_details': {}})

# %%
# %%time
chain.invoke(
    {
        'pet':'dragon', 
        'breed':'night fury'
    }
)
# Out:
# CPU times: user 3.48 ms, sys: 1.37 ms, total: 4.85 ms
# Wall time: 7.81 s
# AIMessage(content='Congratulations on adopting a Night Fury dragon! Training a Night Fury can be challenging due to their independent nature and tendency to be fiercely protective of themselves. Here are some training tips to help you establish a strong bond with your new companion:\n\n1. **Establish trust**: Night Furies are naturally wary of humans, so it\'s essential to earn their trust gradually. Start by offering food and letting them approach you on their own terms.\n2. **Use positive reinforcement**: Reward your dragon with treats, praise, or affection when they exhibit desired behavior, such as responding to commands or performing tricks.\n3. **Be consistent**: Night Furies thrive on routine, so establish a regular training schedule and stick to it. This will help them understand what\'s expected of them.\n4. **Use verbal cues**: Night Furies respond well to vocal commands, so use clear, concise phrases like "sit," "stay," or "come." Avoid yelling or using harsh tones, as this can create anxiety.\n5. **Practice obedience exercises**: Teach your dragon to follow basic commands, such as walking on a leash, performing tricks, or responding to hand signals.\n6. **Respect their boundaries**: Night Furies are fiercely protective of themselves and may become aggressive if they feel threatened or scared. Always respect their personal space and avoid pushing them beyond their comfort zone.\n7. **Provide mental stimulation**: Engage your dragon\'s mind with puzzle toys, problem-solving exercises, or interactive games to keep them mentally stimulated and prevent boredom.\n8. **Use physical exercise**: Night Furies are naturally athletic, so engage them in physical activities like flying, agility training, or obstacle courses to burn off energy and strengthen your bond.\n9. **Be patient**: Training a Night Fury requires time, patience, and understanding. Don\'t expect immediate results, as they may take weeks or even months to adjust to new commands and routines.\n10. **Seek professional guidance**: If you\'re struggling with training your Night Fury or experiencing behavioral issues, consider consulting with a professional dragon trainer or behaviorist for personalized advice.\n\nRemember, every dragon is unique, so be prepared to adapt these tips to suit your Night Fury\'s individual needs and personality.\n\nAdditional resources:\n\n* The Dragon Rider\'s Handbook (a comprehensive guide to dragon care and training)\n* The Night Fury Breed Guide (specific information on the Night Fury breed, including their behavior, habits, and training requirements)\n* Online forums and communities dedicated to dragon breeding and training\n\nStay safe, and enjoy your journey with your new Night Fury companion!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 512, 'prompt_tokens': 44, 'total_tokens': 556, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'llama3.2:3b', 'system_fingerprint': 'fp_ollama', 'id': 'chatcmpl-514', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dcfa0-23b5-7cf1-8766-a60cc0f0239b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 44, 'output_tokens': 512, 'total_tokens': 556, 'input_token_details': {}, 'output_token_details': {}})
