# %% [markdown]
# # Indexing: Creating a Chroma Vectorstore

# %%
pip install chromadb
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders import Docx2txtLoader
from langchain_text_splitters.markdown import MarkdownHeaderTextSplitter
from langchain_text_splitters.character import CharacterTextSplitter
from langchain_community.embeddings import OllamaEmbeddings
from langchain_community.vectorstores import Chroma
from langchain_core.documents import Document

# %%
loader_docx = Docx2txtLoader("./Introduction-to-Data-and-Data-Science-2.docx")
pages = loader_docx.load()

md_splitter = MarkdownHeaderTextSplitter(
    headers_to_split_on = [("#", "Course Title"), 
                           ("##", "Lecture Title")]
)

pages_md_split = md_splitter.split_text(pages[0].page_content)

for i in range(len(pages_md_split)):
    pages_md_split[i].page_content = ' '.join(pages_md_split[i].page_content.split())
    
char_splitter = CharacterTextSplitter(
    separator = ".",
    chunk_size = 500,
    chunk_overlap  = 50
)

pages_char_split = char_splitter.split_documents(pages_md_split)

embedding = OllamaEmbeddings(model='nomic-embed-text')

# %%
len(pages_char_split)
# Out:
# 20

# %%
vectorstore = Chroma.from_documents(
    documents=pages_char_split,
    embedding=embedding,
    persist_directory = "./intro-to-ds-lectures"
)

# %%
vectorstore_from_directory = Chroma(
    persist_directory="./intro-to-ds-lectures",
    embedding_function=embedding
)

# %%
vectorstore_from_directory.get()
# Out:
# {'ids': ['3bdb599d-56bd-4e4a-bea6-457c02973271',
#   'abb90de5-445f-452a-b4e1-911743c92c99',
#   'bb7d98a3-2b80-4cbb-a5d2-15c48e112573',
#   '4dfeee9c-00bc-4346-919d-bc94938da114',
#   'cc1a4fde-6ba2-44fc-ae29-e37c672091d2',
#   '6ef1e17e-dd9f-4faf-9ddb-41b6c8051b6c',
#   '2c383992-dc10-4766-93c4-6c8c968aecc6',
#   '5bb19a6c-6e2a-4b0d-a29b-4aecb2045681',
#   '6db8e268-b047-47d5-b050-ba2541908734',
#   '9b662624-be3d-45f8-876e-d39c620f25dc',
#   '4f664017-ebc0-477c-bbb7-ee823eb7332f',
#   'f627b6c0-5c9c-4819-a4f2-4206b132c7b4',
#   'd4b52baf-f534-4b95-b365-f87b96db5f97',
#   'ccac1738-fe42-4b10-82ab-9f3497c879eb',
#   '40109771-0d70-4055-bc38-aa71873c1f8a',
#   'b3f8510f-78f9-4185-a56c-b2ef49feda00',
#   '01c9bc21-3d65-4b08-9698-c8a1487a0d40',
#   '2f36e757-9dbf-4156-b06f-18d911daa058',
#   '050e910f-d53e-4de9-ae87-2afd71fec1ee',
#   '1baad800-136d-41d6-9de5-e7032bda59f8',
#   '851139aa-dd82-458a-87d6-1871f7afbfbd',
#   '74b5500d-2527-45f2-9c2a-fd57a9cf376b',
# ...

# %%
vectorstore_from_directory.get(
    ids='3bdb599d-56bd-4e4a-bea6-457c02973271',
    include = ["embeddings"]
)
# Out:
# {'ids': ['3bdb599d-56bd-4e4a-bea6-457c02973271'],
#  'embeddings': array([[ 0.8734113 ,  0.7706483 , -2.59848404, -0.2419863 ,  1.43450749,
#          -0.08015253,  1.64579308, -0.86687726, -0.28695518, -0.13578601,
#           0.03132586,  0.50355542,  2.105129  ,  0.5563426 ,  0.66920531,
#          -0.61092746, -0.41188365, -0.72878742, -0.0111571 ,  1.28010118,
#          -0.60221976,  0.42403898, -0.74736732, -0.49973434,  1.30313182,
#          -0.12078824, -1.17890918,  0.60911602, -1.59187508, -0.85242242,
#           1.17608321, -0.04957354,  0.05370752,  0.39452118, -2.80906963,
#          -1.0629555 ,  1.36155736,  1.29121971, -0.58255291, -0.17901324,
#           2.3234005 ,  0.56304514,  0.56524622, -1.64670551,  0.15632766,
#          -0.17896982,  0.07465997, -0.10011768,  0.90377659, -0.90479892,
#          -0.03710681,  0.50407416,  1.12033129,  0.89689708,  1.0022893 ,
#           0.93195349,  1.15555322,  0.64745474,  0.29104903, -0.20128644,
# ...

# %%
added_docuemnt =Document(
    page_content='Alright! So… Let’s discuss the not-so-obvious differences between the terms analysis and analytics. Due to the similarity of the words, some people believe they share the same meaning, and thus use them interchangeably. Technically, this isn’t correct. There is, in fact, a distinct difference between the two. And the reason for one often being used instead of the other is the lack of a transparent understanding of both. So, let’s clear this up, shall we? First, we will start with analysis', 
    metadata={
        'Course Title': 'Introduction to Data and Data Science',
        'Lecture Title': 'Analysis vs Analytics'
    }
)

# %%
vectorstore_from_directory.add_documents([added_docuemnt])
# Out:
# ['713d270b-c8c0-4482-95c1-e3b41c1886d3']

# %%
vectorstore_from_directory.get("713d270b-c8c0-4482-95c1-e3b41c1886d3")
# Out:
# {'ids': ['713d270b-c8c0-4482-95c1-e3b41c1886d3'],
#  'embeddings': None,
#  'documents': ['Alright! So… Let’s discuss the not-so-obvious differences between the terms analysis and analytics. Due to the similarity of the words, some people believe they share the same meaning, and thus use them interchangeably. Technically, this isn’t correct. There is, in fact, a distinct difference between the two. And the reason for one often being used instead of the other is the lack of a transparent understanding of both. So, let’s clear this up, shall we? First, we will start with analysis'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [{'Course Title': 'Introduction to Data and Data Science',
#    'Lecture Title': 'Analysis vs Analytics'}]}

# %%
updated_document = Document(
    page_content='Great! We hope we gave you a good idea about the level of applicability of the most frequently used programming and software tools in the field of data science. Thank you for watching!',
    metadata={
        'Course Title': 'Introduction to Data and Data Science',
        'Lecture Title': 'Programming Languages & Software Employed in Data Science - All the Tools You Need'
        }
)

# %%
vectorstore_from_directory.update_document(
    document_id='713d270b-c8c0-4482-95c1-e3b41c1886d3',
    document=updated_document
)

# %%
vectorstore_from_directory.get("713d270b-c8c0-4482-95c1-e3b41c1886d3")
# Out:
# {'ids': ['713d270b-c8c0-4482-95c1-e3b41c1886d3'],
#  'embeddings': None,
#  'documents': ['Great! We hope we gave you a good idea about the level of applicability of the most frequently used programming and software tools in the field of data science. Thank you for watching!'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [{'Lecture Title': 'Programming Languages & Software Employed in Data Science - All the Tools You Need',
#    'Course Title': 'Introduction to Data and Data Science'}]}

# %%
vectorstore_from_directory.delete('713d270b-c8c0-4482-95c1-e3b41c1886d3')

# %%
vectorstore_from_directory.get("713d270b-c8c0-4482-95c1-e3b41c1886d3")
# Out:
# {'ids': [],
#  'embeddings': None,
#  'documents': [],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': []}
